# %% [markdown]
# <a href="https://colab.research.google.com/github/Dewmi-2003/Machine-Learning/blob/main/ML_Practical_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/popular_shows_dataset.csv")

# %%
print(df)
# Out:
#                                                  title  year   revenue  \
# 0                                              Hoppers  2026  29000000
# 1                                     Reminders of Him  2026  18000000
# 2                                            undertone  2026   9300000
# 3                                             Scream 7  2026   8400000
# 4                                                 GOAT  2026   4700000
# ..                                                 ...   ...       ...
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 999                                          Crime 101  2026   1100000
#
#         imdb_id  tmdb_id  trakt_id
# 0    tt26443616  1327819   1085761
# 1    tt33714084  1367642   1116720
# ...

# %%
print(df.to_string())
# Out:
#                                                        title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0                                                    Hoppers  2026  29000000  tt26443616  1327819   1085761
# 1                                           Reminders of Him  2026  18000000  tt33714084  1367642   1116720
# 2                                                  undertone  2026   9300000  tt35892608  1480387   1213506
# 3                                                   Scream 7  2026   8400000  tt27047903  1159559    934134
# 4                                                       GOAT  2026   4700000  tt27613895  1297842   1057839
# 5                                                 The Bride!  2026   2100000  tt30851137  1159831    934595
# 6                                    Kiki's Delivery Service  1989   1700000   tt0097814    16859     10314
# 7                                        "Wuthering Heights"  2026   1700000  tt32897959  1316092   1077273
# ...

# %%
df.head()
# Out:
#               title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0           Hoppers  2026  29000000  tt26443616  1327819   1085761
# 1  Reminders of Him  2026  18000000  tt33714084  1367642   1116720
# 2         undertone  2026   9300000  tt35892608  1480387   1213506
# 3          Scream 7  2026   8400000  tt27047903  1159559    934134
# 4              GOAT  2026   4700000  tt27613895  1297842   1057839

# %%
df.shape
# Out:
# (1000, 6)

# %%
df.columns
# Out:
# Index(['title', 'year', 'revenue', 'imdb_id', 'tmdb_id', 'trakt_id'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   year      1000 non-null   int64
#  2   revenue   1000 non-null   int64
#  3   imdb_id   1000 non-null   object
#  4   tmdb_id   1000 non-null   int64
#  5   trakt_id  1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
df.tail()
# Out:
#                                                  title  year  revenue  \
# 995                                         The Bride!  2026  2100000
# 996                            Kiki's Delivery Service  1989  1700000
# 997                                "Wuthering Heights"  2026  1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991  1500000
# 999                                          Crime 101  2026  1100000
#
#         imdb_id  tmdb_id  trakt_id
# 995  tt30851137  1159831    934595
# 996   tt0097814    16859     10314
# 997  tt32897959  1316092   1077273
# 998   tt0103060     1497       991
# 999  tt32430579  1171145    944042

# %%
df.head(10)
# Out:
#                                                title  year   revenue  \
# 0                                            Hoppers  2026  29000000
# 1                                   Reminders of Him  2026  18000000
# 2                                          undertone  2026   9300000
# 3                                           Scream 7  2026   8400000
# 4                                               GOAT  2026   4700000
# 5                                         The Bride!  2026   2100000
# 6                            Kiki's Delivery Service  1989   1700000
# 7                                "Wuthering Heights"  2026   1700000
# 8  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 9                                          Crime 101  2026   1100000
#
#       imdb_id  tmdb_id  trakt_id
# 0  tt26443616  1327819   1085761
# 1  tt33714084  1367642   1116720
# 2  tt35892608  1480387   1213506
# 3  tt27047903  1159559    934134
# 4  tt27613895  1297842   1057839
# ...

# %%
df.describe()
# Out:
#               year       revenue       tmdb_id      trakt_id
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03
# mean   2018.800000  7.750000e+06  1.029867e+06  8.375175e+05
# std      14.414152  8.705877e+06  5.195836e+05  4.246083e+05
# min    1989.000000  1.100000e+06  1.497000e+03  9.910000e+02
# 25%    2026.000000  1.700000e+06  1.159559e+06  9.341340e+05
# 50%    2026.000000  3.400000e+06  1.234494e+06  1.000940e+06
# 75%    2026.000000  9.300000e+06  1.327819e+06  1.085761e+06
# max    2026.000000  2.900000e+07  1.480387e+06  1.213506e+06

# %% [markdown]
# ##Selecting Columns

# %%
df['title']
# Out:
# 0                                                Hoppers
# 1                                       Reminders of Him
# 2                                              undertone
# 3                                               Scream 7
# 4                                                   GOAT
#                              ...
# 995                                           The Bride!
# 996                              Kiki's Delivery Service
# 997                                  "Wuthering Heights"
# 998    Teenage Mutant Ninja Turtles II: The Secret of...
# 999                                            Crime 101
# Name: title, Length: 1000, dtype: object

# %%
df[["title","year","revenue"]]
# Out:
#                                                  title  year   revenue
# 0                                              Hoppers  2026  29000000
# 1                                     Reminders of Him  2026  18000000
# 2                                            undertone  2026   9300000
# 3                                             Scream 7  2026   8400000
# 4                                                 GOAT  2026   4700000
# ..                                                 ...   ...       ...
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 999                                          Crime 101  2026   1100000
#
# [1000 rows x 3 columns]

# %% [markdown]
# ##Selecting Rows

# %%
df.loc[0]
# Out:
# title          Hoppers
# year              2026
# revenue       29000000
# imdb_id     tt26443616
# tmdb_id        1327819
# trakt_id       1085761
# Name: 0, dtype: object

# %%
df.iloc[0:5]
# Out:
#               title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0           Hoppers  2026  29000000  tt26443616  1327819   1085761
# 1  Reminders of Him  2026  18000000  tt33714084  1367642   1116720
# 2         undertone  2026   9300000  tt35892608  1480387   1213506
# 3          Scream 7  2026   8400000  tt27047903  1159559    934134
# 4              GOAT  2026   4700000  tt27613895  1297842   1057839

# %% [markdown]
# ##Using lables/Conditions

# %%
df.loc[0]
# Out:
# title          Hoppers
# year              2026
# revenue       29000000
# imdb_id     tt26443616
# tmdb_id        1327819
# trakt_id       1085761
# Name: 0, dtype: object

# %%
df[df['revenue']>=29000000]
# Out:
#        title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0    Hoppers  2026  29000000  tt26443616  1327819   1085761
# 10   Hoppers  2026  29000000  tt26443616  1327819   1085761
# 20   Hoppers  2026  29000000  tt26443616  1327819   1085761
# 30   Hoppers  2026  29000000  tt26443616  1327819   1085761
# 40   Hoppers  2026  29000000  tt26443616  1327819   1085761
# ..       ...   ...       ...         ...      ...       ...
# 950  Hoppers  2026  29000000  tt26443616  1327819   1085761
# 960  Hoppers  2026  29000000  tt26443616  1327819   1085761
# 970  Hoppers  2026  29000000  tt26443616  1327819   1085761
# 980  Hoppers  2026  29000000  tt26443616  1327819   1085761
# 990  Hoppers  2026  29000000  tt26443616  1327819   1085761
#
# [100 rows x 6 columns]

# %%
df[df['year']==2026]
# Out:
#                    title  year   revenue     imdb_id  tmdb_id  trakt_id
# 0                Hoppers  2026  29000000  tt26443616  1327819   1085761
# 1       Reminders of Him  2026  18000000  tt33714084  1367642   1116720
# 2              undertone  2026   9300000  tt35892608  1480387   1213506
# 3               Scream 7  2026   8400000  tt27047903  1159559    934134
# 4                   GOAT  2026   4700000  tt27613895  1297842   1057839
# ..                   ...   ...       ...         ...      ...       ...
# 993             Scream 7  2026   8400000  tt27047903  1159559    934134
# 994                 GOAT  2026   4700000  tt27613895  1297842   1057839
# 995           The Bride!  2026   2100000  tt30851137  1159831    934595
# 997  "Wuthering Heights"  2026   1700000  tt32897959  1316092   1077273
# 999            Crime 101  2026   1100000  tt32430579  1171145    944042
#
# [800 rows x 6 columns]

# %% [markdown]
# ## Filtering Data

# %%
df[df["title"]=="Crime 101"]
# Out:
#          title  year  revenue     imdb_id  tmdb_id  trakt_id
# 9    Crime 101  2026  1100000  tt32430579  1171145    944042
# 19   Crime 101  2026  1100000  tt32430579  1171145    944042
# 29   Crime 101  2026  1100000  tt32430579  1171145    944042
# 39   Crime 101  2026  1100000  tt32430579  1171145    944042
# 49   Crime 101  2026  1100000  tt32430579  1171145    944042
# ..         ...   ...      ...         ...      ...       ...
# 959  Crime 101  2026  1100000  tt32430579  1171145    944042
# 969  Crime 101  2026  1100000  tt32430579  1171145    944042
# 979  Crime 101  2026  1100000  tt32430579  1171145    944042
# 989  Crime 101  2026  1100000  tt32430579  1171145    944042
# 999  Crime 101  2026  1100000  tt32430579  1171145    944042
#
# [100 rows x 6 columns]

# %%
df[(df['revenue']>=29000000)&(df['year']=="2026")]
# Out:
# Empty DataFrame
# Columns: [title, year, revenue, imdb_id, tmdb_id, trakt_id]
# Index: []

# %% [markdown]
# ##Handling missing values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     1000 non-null   object
#  1   year      1000 non-null   int64
#  2   revenue   1000 non-null   int64
#  3   imdb_id   1000 non-null   object
#  4   tmdb_id   1000 non-null   int64
#  5   trakt_id  1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                                                  title  year   revenue  \
# 0                                              Hoppers  2026  29000000
# 1                                     Reminders of Him  2026  18000000
# 2                                            undertone  2026   9300000
# 3                                             Scream 7  2026   8400000
# 4                                                 GOAT  2026   4700000
# ..                                                 ...   ...       ...
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 999                                          Crime 101  2026   1100000
#
#         imdb_id  tmdb_id  trakt_id
# 0    tt26443616  1327819   1085761
# ...

# %% [markdown]
# ##Remove missing values

# %%
df.dropna()
# Out:
#                                                  title  year   revenue  \
# 0                                              Hoppers  2026  29000000
# 1                                     Reminders of Him  2026  18000000
# 2                                            undertone  2026   9300000
# 3                                             Scream 7  2026   8400000
# 4                                                 GOAT  2026   4700000
# ..                                                 ...   ...       ...
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 999                                          Crime 101  2026   1100000
#
#         imdb_id  tmdb_id  trakt_id
# 0    tt26443616  1327819   1085761
# 1    tt33714084  1367642   1116720
# ...

# %% [markdown]
# ##Fill missing values

# %%
df.fillna(0)
# Out:
#                                                  title  year   revenue  \
# 0                                              Hoppers  2026  29000000
# 1                                     Reminders of Him  2026  18000000
# 2                                            undertone  2026   9300000
# 3                                             Scream 7  2026   8400000
# 4                                                 GOAT  2026   4700000
# ..                                                 ...   ...       ...
# 995                                         The Bride!  2026   2100000
# 996                            Kiki's Delivery Service  1989   1700000
# 997                                "Wuthering Heights"  2026   1700000
# 998  Teenage Mutant Ninja Turtles II: The Secret of...  1991   1500000
# 999                                          Crime 101  2026   1100000
#
#         imdb_id  tmdb_id  trakt_id
# 0    tt26443616  1327819   1085761
# 1    tt33714084  1367642   1116720
# ...

# %%
df['revenue'].fillna(df['revenue'].mean())
# Out:
# 0      29000000
# 1      18000000
# 2       9300000
# 3       8400000
# 4       4700000
#          ...
# 995     2100000
# 996     1700000
# 997     1700000
# 998     1500000
# 999     1100000
# Name: revenue, Length: 1000, dtype: int64
